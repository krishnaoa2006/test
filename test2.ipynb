# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

sns.set_theme(style='darkgrid')

# %%
df=pd.read_csv('simple_logistic.csv')
print("dataset:")
print(df.head())

plt.figure(figsize=(8,5))
plt.scatter(df['hours'],df['pass'],c=df['pass'],cmap='bwr',edgecolor='k')
plt.xlabel('hours studied')
plt.ylabel("pass(1)/fail(0)")
plt.title('hours vs result')
plt.show()
# Out:
# dataset:
#    hours  pass
# 0    0.5     0
# 1    1.0     0
# 2    1.5     0
# 3    2.0     0
# 4    2.5     0

# %%
x=df[['hours']]
y=df['pass']
model=LogisticRegression()
model.fit(x,y)
print("model trained successfully.")
# Out:
# model trained successfully.

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['hours'],df['pass'],c=df['pass'],cmap='bwr',label='data points')
x_test_range=np.linspace(0,10,100).reshape(-1,1)
y_prob_range=model.predict_proba(x_test_range)[:,1]
plt.plot(x_test_range,y_prob_range,color='green',linewidth=3,label='logistic curve')
plt.axhline(y=0.5,color='gray',linestyle='--',label='decision boundary(0.5)')
plt.xlabel('hours studied')
plt.ylabel('probability of passing')
plt.title('logistic regression sigmoid curve')
plt.legend()
plt.show()
# Out:
# c:\Users\krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
try:
    user_hours=float(input("enter study hours (0-12):"))
    x_user=np.array([[user_hours]])
    prediction=model.predict(x_user)
    probability=model.predict_proba(x_user)[0][1]
    if prediction==1:
        print(f"\nresult:pass")
        print(f"confidence: {probability*100:.2f}%")
    else:
        print(f"\nresult:fail")
        print(f"confidence:{(1-probability)*100:.2f}%")
except ValueError:
    print("invalid input.please enter a numerical value for hours.")
# Out:
# result:pass
# confidence: 100.00%
# c:\Users\krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
