# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

# %%
df = pd.read_csv("user_behavior_dataset.csv")
print(df.columns)
x = df[['Screen On Time (hours/day)']]
y = df['Battery Drain (mAh/day)']
# Out:
# Index(['User ID', 'Device Model', 'Operating System',
#        'App Usage Time (min/day)', 'Screen On Time (hours/day)',
#        'Battery Drain (mAh/day)', 'Number of Apps Installed',
#        'Data Usage (MB/day)', 'Age', 'Gender', 'User Behavior Class'],
#       dtype='str')

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"mean absolute error: {mae:.2f}")
print(f"r-squared score: {r2:2f}")
# Out:
# mean absolute error: 205.78
# r-squared score: 0.892433

# %%
hours = [[6]]
prediction = model.predict(hours)
print("Battery Drain for 6 hrs screen time:", prediction[0])
plt.scatter(x, y, color='blue')
plt.plot(x, model.predict(x), color='red')
plt.xlabel("Screen On Time")
plt.ylabel("Battery Drain")
plt.title("Battery Drain Prediction")
plt.show()
# Out:
# Battery Drain for 6 hrs screen time: 1710.8321238872945
# c:\Users\krish\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
